# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
DF = pd.read_csv('C:\\Users\\maciej.olech\\Desktop\\structure_files\\D.csv')

# %%
DF
# Out:
#       BLUP_ZWH    S1    S2  BLUP_MIOT  RASA  OSHZ  NR_CHLEW     NR_LOCHY  \
# 0      10.1606 -0.05 -0.16          3    10     6       501      I337/19
# 1      11.3550  3.22  2.33         16    10     6       501    I3423A/14
# 2      11.4496  2.50  2.22         16    10     6       501    I3433A/14
# 3      10.3660  0.57  0.57          3    10     6       501      I344/19
# 4      10.2104  0.06  0.34          4    10     6       501      I354/19
# ...        ...   ...   ...        ...   ...   ...       ...          ...
# 2080   10.0720  0.59  1.04          1    90    26       373  26373688620
# 2081    9.9458  0.44  0.87          1    90    26       373  26373688820
# 2082   10.2600  0.75  1.20          1    90    26       373  26373688920
# 2083    9.9805  0.46  0.86          1    90    26       373  26373690020
# 2084    9.9329  0.46  0.20          1    90    26       373  26373719220
#
#       H_PD  H_PM  ...  H_IN_1  H_IN_2  H_IN_3  H_IN_4  H_IN_5  H_IN_6  Week  \
# ...

# %%
sns.relplot(data=DF,x="RASA",y="BLUP_MIOT",kind='line',aspect=2)
plt.show()
